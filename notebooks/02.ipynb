# %%
##############奥运五环##########
import turtle
turtle.color("blue")#输入颜色
turtle.penup()#笔抬起来
turtle.goto(-110,-25)#挪动位置
turtle.pendown()#笔放下来
turtle.circle(45)#划线

turtle.color("black")
turtle.penup()
turtle.goto(0,-25)
turtle.pendown()
turtle.circle(45)

turtle.color("red")
turtle.penup()
turtle.goto(110,-25)
turtle.pendown()
turtle.circle(45)

turtle.color("yellow")
turtle.penup()
turtle.goto(-55,-75)
turtle.pendown()
turtle.circle(45)

turtle.color("green")
turtle.penup()
turtle.goto(55,-75)
turtle.pendown()
turtle.circle(45)

turtle.done()
# Out:
# 1   HIToolbox                           0x00007ff81ad97726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff81ad972b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff81ad06cd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff81ad97173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff81425a287 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff8140af055 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   CoreFoundation                      0x00007ff810e896c6 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff810f22cac ___CFXRegistrationPost_block_invoke + 86
# ...
